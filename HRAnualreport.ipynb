# %% [markdown]
# <a href="https://colab.research.google.com/github/wissam-93/Analytics/blob/main/HRAnualreport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime
df = pd.read_csv('HR_Analysis.csv')
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#            id  first_name  last_name   birthdate  gender  \
# 0  00-0076100     Terrell       Suff   4/11/1994  Female
# 1  00-0381660  Wainwright   Corfield  12/13/1996    Male
# 2  00-1052230        Elmo      McNee  12/16/1988  Female
# 3  00-1100714       Regen    Nafzger    4/6/1990    Male
# 4  00-1189819      Rudolf  Reichardt    6/5/1979    Male
#
#                         race            department  \
# 0          Two or More Races    Product Management
# 1                      Asian           Engineering
# 2  Black or African American              Services
# 3                      White       Human Resources
# 4  Black or African American  Business Development
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
# ...

# %%
df.isnull().sum()
# Out:
# id                0
# first_name        0
# last_name         0
# birthdate         0
# gender            0
# race              0
# department        0
# job_title         0
# location          0
# hire_date         0
# termdate          0
# location_city     0
# location_state    0
# dtype: int64

# %%
x = df['hire_date'].count()
y = df['termdate'].count()

# %%
df.termdate.max()
# Out:
# 2041

# %%
df.termdate.min()
# Out:
# 2001

# %%
df.head(3)
# Out:
#            id  first_name last_name   birthdate  gender  \
# 0  00-0076100     Terrell      Suff   4/11/1994  Female
# 1  00-0381660  Wainwright  Corfield  12/13/1996    Male
# 2  00-1052230        Elmo     McNee  12/16/1988  Female
#
#                         race          department  \
# 0          Two or More Races  Product Management
# 1                      Asian         Engineering
# 2  Black or African American            Services
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
#
#   location_city location_state
# 0         Flint       Michigan
# 1     Cleveland           Ohio
# 2     Cleveland           Ohio

# %%
df['length_service'] = df['termdate']-df['hire_date']

# %%
df.head()
# Out:
#            id  first_name  last_name   birthdate  gender  \
# 0  00-0076100     Terrell       Suff   4/11/1994  Female
# 1  00-0381660  Wainwright   Corfield  12/13/1996    Male
# 2  00-1052230        Elmo      McNee  12/16/1988  Female
# 3  00-1100714       Regen    Nafzger    4/6/1990    Male
# 4  00-1189819      Rudolf  Reichardt    6/5/1979    Male
#
#                         race            department  \
# 0          Two or More Races    Product Management
# 1                      Asian           Engineering
# 2  Black or African American              Services
# 3                      White       Human Resources
# 4  Black or African American  Business Development
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
# ...

# %%
df.query("length_service == 10").value_counts().sum()
# Out:
# 173

# %%
df.shape
# Out:
# (3929, 14)

# %%
df['length_service'].mean()
# Out:
# 10.440570119623313

# %%
import numpy as np
round(np.mean(df['termdate']-df['hire_date']),0)
# Out:
# 10.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3929 non-null   object
#  1   first_name      3929 non-null   object
#  2   last_name       3929 non-null   object
#  3   birthdate       3929 non-null   object
#  4   gender          3929 non-null   object
#  5   race            3929 non-null   object
#  6   department      3929 non-null   object
#  7   job_title       3929 non-null   object
#  8   location        3929 non-null   object
#  9   hire_date       3929 non-null   int64
#  10  termdate        3929 non-null   int64
#  11  location_city   3929 non-null   object
#  12  location_state  3929 non-null   object
#  13  length_service  3929 non-null   int64
# dtypes: int64(3), object(11)
# memory usage: 429.9+ KB

# %%
df["Churn"] = df.termdate >=2022

# %%
df.head()
# Out:
#            id  first_name  last_name   birthdate  gender  \
# 0  00-0076100     Terrell       Suff   4/11/1994  Female
# 1  00-0381660  Wainwright   Corfield  12/13/1996    Male
# 2  00-1052230        Elmo      McNee  12/16/1988  Female
# 3  00-1100714       Regen    Nafzger    4/6/1990    Male
# 4  00-1189819      Rudolf  Reichardt    6/5/1979    Male
#
#                         race            department  \
# 0          Two or More Races    Product Management
# 1                      Asian           Engineering
# 2  Black or African American              Services
# 3                      White       Human Resources
# 4  Black or African American  Business Development
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
# ...

# %%
df["Churn"]= df["Churn"].replace(True,'Active')
df["Churn"]= df["Churn"].replace(False,'Quit')

# %%
df['Churn'].value_counts()
# Out:
# Quit      2103
# Active    1826
# Name: Churn, dtype: int64

# %%
current_year = datetime.datetime.now().year
current_year
# Out:
# 2022

# %%
df['Age'] = df['birthdate']

# %%
df.head()
# Out:
#            id  first_name  last_name   birthdate  gender  \
# 0  00-0076100     Terrell       Suff   4/11/1994  Female
# 1  00-0381660  Wainwright   Corfield  12/13/1996    Male
# 2  00-1052230        Elmo      McNee  12/16/1988  Female
# 3  00-1100714       Regen    Nafzger    4/6/1990    Male
# 4  00-1189819      Rudolf  Reichardt    6/5/1979    Male
#
#                         race            department  \
# 0          Two or More Races    Product Management
# 1                      Asian           Engineering
# 2  Black or African American              Services
# 3                      White       Human Resources
# 4  Black or African American  Business Development
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
# ...

# %%
df['Age'] = pd.to_datetime(df['Age'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3929 non-null   object
#  1   first_name      3929 non-null   object
#  2   last_name       3929 non-null   object
#  3   birthdate       3929 non-null   object
#  4   gender          3929 non-null   object
#  5   race            3929 non-null   object
#  6   department      3929 non-null   object
#  7   job_title       3929 non-null   object
#  8   location        3929 non-null   object
#  9   hire_date       3929 non-null   int64
#  10  termdate        3929 non-null   int64
#  11  location_city   3929 non-null   object
#  12  location_state  3929 non-null   object
#  13  length_service  3929 non-null   int64
#  14  Churn           3929 non-null   object
#  15  Age             3929 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(12)
# ...

# %%
df.head()
# Out:
#            id  first_name  last_name   birthdate  gender  \
# 0  00-0076100     Terrell       Suff   4/11/1994  Female
# 1  00-0381660  Wainwright   Corfield  12/13/1996    Male
# 2  00-1052230        Elmo      McNee  12/16/1988  Female
# 3  00-1100714       Regen    Nafzger    4/6/1990    Male
# 4  00-1189819      Rudolf  Reichardt    6/5/1979    Male
#
#                         race            department  \
# 0          Two or More Races    Product Management
# 1                      Asian           Engineering
# 2  Black or African American              Services
# 3                      White       Human Resources
# 4  Black or African American  Business Development
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
# ...

# %%
df['Current Year'] = datetime.datetime.now().year

# %%
df.head()
# Out:
#            id  first_name  last_name   birthdate  gender  \
# 0  00-0076100     Terrell       Suff   4/11/1994  Female
# 1  00-0381660  Wainwright   Corfield  12/13/1996    Male
# 2  00-1052230        Elmo      McNee  12/16/1988  Female
# 3  00-1100714       Regen    Nafzger    4/6/1990    Male
# 4  00-1189819      Rudolf  Reichardt    6/5/1979    Male
#
#                         race            department  \
# 0          Two or More Races    Product Management
# 1                      Asian           Engineering
# 2  Black or African American              Services
# 3                      White       Human Resources
# 4  Black or African American  Business Development
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
# ...

# %%
df['Age'] = pd.to_datetime(df['Age'],format = "%Y",errors='coerce').dt.strftime('%Y')
df['Current Year'] = pd.to_datetime(df['Current Year'],format = "%Y",errors='coerce').dt.strftime('%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3929 non-null   object
#  1   first_name      3929 non-null   object
#  2   last_name       3929 non-null   object
#  3   birthdate       3929 non-null   object
#  4   gender          3929 non-null   object
#  5   race            3929 non-null   object
#  6   department      3929 non-null   object
#  7   job_title       3929 non-null   object
#  8   location        3929 non-null   object
#  9   hire_date       3929 non-null   int64
#  10  termdate        3929 non-null   int64
#  11  location_city   3929 non-null   object
#  12  location_state  3929 non-null   object
#  13  length_service  3929 non-null   int64
#  14  Churn           3929 non-null   object
#  15  Age             3929 non-null   object
#  16  Current Year    3929 non-null   object
# ...

# %%
df.head()
# Out:
#            id  first_name  last_name   birthdate  gender  \
# 0  00-0076100     Terrell       Suff   4/11/1994  Female
# 1  00-0381660  Wainwright   Corfield  12/13/1996    Male
# 2  00-1052230        Elmo      McNee  12/16/1988  Female
# 3  00-1100714       Regen    Nafzger    4/6/1990    Male
# 4  00-1189819      Rudolf  Reichardt    6/5/1979    Male
#
#                         race            department  \
# 0          Two or More Races    Product Management
# 1                      Asian           Engineering
# 2  Black or African American              Services
# 3                      White       Human Resources
# 4  Black or African American  Business Development
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
# ...

# %%
df['Current_Year'] = df['Current Year'] 
df['age'] = df['Age']

# %%
df["age"] = df["age"].astype(str).astype(int)
df["Current_Year"] = df["Current_Year"].astype(str).astype(int)

# %%
df.head()
# Out:
#            id  first_name  last_name   birthdate  gender  \
# 0  00-0076100     Terrell       Suff   4/11/1994  Female
# 1  00-0381660  Wainwright   Corfield  12/13/1996    Male
# 2  00-1052230        Elmo      McNee  12/16/1988  Female
# 3  00-1100714       Regen    Nafzger    4/6/1990    Male
# 4  00-1189819      Rudolf  Reichardt    6/5/1979    Male
#
#                         race            department  \
# 0          Two or More Races    Product Management
# 1                      Asian           Engineering
# 2  Black or African American              Services
# 3                      White       Human Resources
# 4  Black or African American  Business Development
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
# ...

# %%
df['Current_Age'] =df['Current_Year']-df['age']

# %%
df.head(1)
# Out:
#            id first_name last_name  birthdate  gender               race  \
# 0  00-0076100    Terrell      Suff  4/11/1994  Female  Two or More Races
#
#            department         job_title location  hire_date  termdate  \
# 0  Product Management  Business Analyst   Remote       2010      2029
#
#   location_city location_state  length_service   Churn   Age Current Year  \
# 0         Flint       Michigan              19  Active  1994         2022
#
#    Current_Year   age  Current_Age
# 0          2022  1994           28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3929 non-null   object
#  1   first_name      3929 non-null   object
#  2   last_name       3929 non-null   object
#  3   birthdate       3929 non-null   object
#  4   gender          3929 non-null   object
#  5   race            3929 non-null   object
#  6   department      3929 non-null   object
#  7   job_title       3929 non-null   object
#  8   location        3929 non-null   object
#  9   hire_date       3929 non-null   int64
#  10  termdate        3929 non-null   int64
#  11  location_city   3929 non-null   object
#  12  location_state  3929 non-null   object
#  13  length_service  3929 non-null   int64
#  14  Churn           3929 non-null   object
#  15  Age             3929 non-null   object
#  16  Current Year    3929 non-null   object
# ...

# %%
df.drop(['Current Year','Age'], axis=1,inplace =True)

# %%
df.head()

# %%
round(np.mean(df.Current_Age),0)
# Out:
# 38.0

# %%
df.to_csv('HR_Analytics.csv',index = False)

# %%
df3 = pd.read_csv('HR_Analytics.csv')
df3.head()

# %%
df.head()
# Out:
#            id  first_name  last_name   birthdate  gender  \
# 0  00-0076100     Terrell       Suff   4/11/1994  Female
# 1  00-0381660  Wainwright   Corfield  12/13/1996    Male
# 2  00-1052230        Elmo      McNee  12/16/1988  Female
# 3  00-1100714       Regen    Nafzger    4/6/1990    Male
# 4  00-1189819      Rudolf  Reichardt    6/5/1979    Male
#
#                         race            department  \
# 0          Two or More Races    Product Management
# 1                      Asian           Engineering
# 2  Black or African American              Services
# 3                      White       Human Resources
# 4  Black or African American  Business Development
#
#                               job_title      location  hire_date  termdate  \
# 0                      Business Analyst        Remote       2010      2029
# 1  Business Systems Development Analyst  Headquarters       2001      2008
# 2                       Service Manager  Headquarters       2002      2006
# ...

# %%
df['length_service'].mean()
# Out:
# 10.440570119623313

# %%
df['Churn'].value_counts(normalize = True)
# Out:
# Quit      0.535251
# Active    0.464749
# Name: Churn, dtype: float64
